# %%
import importlib

from src.processing.rf import split_data
from src.processing.rf import create_data
from src.data import shape_processor
import geopandas as gpd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from src.data import gedi_pipeline
import seaborn as sns
from fastai.tabular.all import load_pickle
from src.constants import DATA_PATH
importlib.reload(gedi_pipeline)
importlib.reload(split_data)
importlib.reload(create_data)
# Out:
# 2023-06-15 22:44:40,994 DEBUG: Logger /home/jk871/fire-regen/src/data/gedi_pipeline.py already set up. [in get_logger at /home/jk871/fire-regen/src/utils/logging_util.py:51]
# 2023-06-15 22:44:40,996 DEBUG: Logger /home/jk871/fire-regen/src/processing/rf/create_data.py already set up. [in get_logger at /home/jk871/fire-regen/src/utils/logging_util.py:51]
# <module 'src.processing.rf.create_data' from '/home/jk871/fire-regen/src/processing/rf/create_data.py'>

# %% [markdown]
# ## Create Inference Data

# %% [markdown]
# ### 3x3 filtered GEDI shots.

# %%
# Obtain GEDI data.
gedi_burned, _ = gedi_pipeline.load_stage_9(3)

# %%
create_data.create_and_save_data_for_rf(gedi_burned, 1984, 2020, save=True, save_folder=f"{DATA_PATH}/rf/burned/3x3")
# Out:
# 2023-06-15 22:45:17,191 DEBUG: Matching gedi shots from 1984 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 22:45:17,205 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 22:55:31,109 DEBUG: Save DF in a pickle file. Training data for year 1985 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 22:55:31,339 DEBUG: Matching gedi shots from 1985 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 22:55:31,350 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 22:57:59,375 DEBUG: Save DF in a pickle file. Training data for year 1986 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 22:58:00,021 DEBUG: Matching gedi shots from 1986 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 22:58:00,045 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 22:59:04,928 DEBUG: Save DF in a pickle file. Training data for year 1987 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 22:59:05,659 DEBUG: Matching gedi shots from 1987 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 22:59:05,677 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:01:48,399 DEBUG: Save DF in a pickle file. Training data for year 1988 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:01:48,913 DEBUG: Matching gedi shots from 1988 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:01:48,930 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:05:09,547 DEBUG: Save DF in a pickle file. Training data for year 1989 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:05:10,069 DEBUG: Dropping columns from 1984 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:05:10,097 DEBUG: Matching gedi shots from 1989 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:05:10,165 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:06:10,945 DEBUG: Save DF in a pickle file. Training data for year 1990 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:06:11,559 DEBUG: Dropping columns from 1985 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:06:11,574 DEBUG: Matching gedi shots from 1990 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:06:11,586 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:08:58,206 DEBUG: Save DF in a pickle file. Training data for year 1991 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:08:58,972 DEBUG: Dropping columns from 1986 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:08:59,005 DEBUG: Matching gedi shots from 1991 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:08:59,022 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:11:56,751 DEBUG: Save DF in a pickle file. Training data for year 1992 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:11:57,501 DEBUG: Dropping columns from 1987 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:11:57,556 DEBUG: Matching gedi shots from 1992 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:11:57,566 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:14:50,691 DEBUG: Save DF in a pickle file. Training data for year 1993 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:14:51,483 DEBUG: Dropping columns from 1988 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:14:51,531 DEBUG: Matching gedi shots from 1993 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:14:51,545 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:16:50,167 DEBUG: Save DF in a pickle file. Training data for year 1994 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:16:50,834 DEBUG: Dropping columns from 1989 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:16:50,900 DEBUG: Matching gedi shots from 1994 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:16:50,911 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:18:17,459 DEBUG: Save DF in a pickle file. Training data for year 1995 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:18:18,185 DEBUG: Dropping columns from 1990 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:18:18,203 DEBUG: Matching gedi shots from 1995 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:18:18,219 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:19:40,623 DEBUG: Save DF in a pickle file. Training data for year 1996 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:19:41,414 DEBUG: Dropping columns from 1991 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:19:41,439 DEBUG: Matching gedi shots from 1996 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:19:41,455 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:21:20,007 DEBUG: Save DF in a pickle file. Training data for year 1997 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:21:20,729 DEBUG: Dropping columns from 1992 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:21:20,757 DEBUG: Matching gedi shots from 1997 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:21:20,774 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:23:18,674 DEBUG: Save DF in a pickle file. Training data for year 1998 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:23:19,340 DEBUG: Dropping columns from 1993 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:23:19,367 DEBUG: Matching gedi shots from 1998 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:23:19,384 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:26:29,202 DEBUG: Save DF in a pickle file. Training data for year 1999 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:26:29,985 DEBUG: Dropping columns from 1994 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:26:30,013 DEBUG: Matching gedi shots from 1999 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:26:30,026 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:28:06,399 DEBUG: Save DF in a pickle file. Training data for year 2000 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:28:06,904 DEBUG: Dropping columns from 1995 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:28:06,927 DEBUG: Matching gedi shots from 2000 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:28:06,945 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:30:15,876 DEBUG: Save DF in a pickle file. Training data for year 2001 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:30:16,677 DEBUG: Dropping columns from 1996 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:30:16,706 DEBUG: Matching gedi shots from 2001 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:30:16,722 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:34:47,290 DEBUG: Save DF in a pickle file. Training data for year 2002 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:34:48,040 DEBUG: Dropping columns from 1997 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:34:48,083 DEBUG: Matching gedi shots from 2002 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:34:48,099 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:37:32,247 DEBUG: Save DF in a pickle file. Training data for year 2003 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:37:32,804 DEBUG: Dropping columns from 1998 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:37:32,825 DEBUG: Matching gedi shots from 2003 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:37:32,840 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:39:10,548 DEBUG: Save DF in a pickle file. Training data for year 2004 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:39:11,151 DEBUG: Dropping columns from 1999 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:39:11,187 DEBUG: Matching gedi shots from 2004 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:39:11,206 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:40:44,389 DEBUG: Save DF in a pickle file. Training data for year 2005 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:40:44,792 DEBUG: Dropping columns from 2000 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:40:44,820 DEBUG: Matching gedi shots from 2005 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:40:44,838 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:42:31,132 DEBUG: Save DF in a pickle file. Training data for year 2006 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:42:31,955 DEBUG: Dropping columns from 2001 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:42:31,980 DEBUG: Matching gedi shots from 2006 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:42:31,995 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:45:02,262 DEBUG: Save DF in a pickle file. Training data for year 2007 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:45:02,737 DEBUG: Dropping columns from 2002 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:45:02,771 DEBUG: Matching gedi shots from 2007 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:45:02,784 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:49:09,976 DEBUG: Save DF in a pickle file. Training data for year 2008 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:49:10,725 DEBUG: Dropping columns from 2003 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:49:10,767 DEBUG: Matching gedi shots from 2008 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:49:10,778 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:51:42,668 DEBUG: Save DF in a pickle file. Training data for year 2009 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:51:43,439 DEBUG: Dropping columns from 2004 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:51:43,527 DEBUG: Matching gedi shots from 2009 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:51:43,540 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:53:25,000 DEBUG: Save DF in a pickle file. Training data for year 2010 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:53:25,560 DEBUG: Dropping columns from 2005 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:53:25,592 DEBUG: Matching gedi shots from 2010 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:53:25,610 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:56:23,769 DEBUG: Save DF in a pickle file. Training data for year 2011 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:56:24,502 DEBUG: Dropping columns from 2006 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:56:24,561 DEBUG: Matching gedi shots from 2011 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:56:24,572 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-15 23:57:48,611 DEBUG: Save DF in a pickle file. Training data for year 2012 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-15 23:57:49,095 DEBUG: Dropping columns from 2007 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-15 23:57:49,123 DEBUG: Matching gedi shots from 2012 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-15 23:57:49,139 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:00:07,847 DEBUG: Save DF in a pickle file. Training data for year 2013 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:00:08,546 DEBUG: Dropping columns from 2008 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 00:00:08,589 DEBUG: Matching gedi shots from 2013 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:00:08,607 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:03:20,715 DEBUG: Save DF in a pickle file. Training data for year 2014 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:03:21,512 DEBUG: Dropping columns from 2009 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 00:03:21,536 DEBUG: Matching gedi shots from 2014 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:03:21,555 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:05:21,049 DEBUG: Save DF in a pickle file. Training data for year 2015 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:05:21,770 DEBUG: Dropping columns from 2010 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 00:05:21,800 DEBUG: Matching gedi shots from 2015 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:05:21,817 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:09:13,758 DEBUG: Save DF in a pickle file. Training data for year 2016 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:09:14,194 DEBUG: Dropping columns from 2011 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 00:09:14,232 DEBUG: Matching gedi shots from 2016 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:09:14,250 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:12:11,927 DEBUG: Save DF in a pickle file. Training data for year 2017 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:12:12,485 DEBUG: Dropping columns from 2012 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 00:12:12,527 DEBUG: Matching gedi shots from 2017 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:12:12,540 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:15:28,718 DEBUG: Save DF in a pickle file. Training data for year 2018 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:15:29,369 DEBUG: Dropping columns from 2013 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 00:15:29,431 DEBUG: Matching gedi shots from 2018 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:15:29,440 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:18:56,929 DEBUG: Save DF in a pickle file. Training data for year 2019 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:18:58,344 DEBUG: Dropping columns from 2014 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 00:18:58,375 DEBUG: Matching gedi shots from 2019 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:19:00,611 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:20:34,952 DEBUG: Save DF in a pickle file. Training data for year 2020 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:20:35,675 DEBUG: Dropping columns from 2015 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
#                  shot_number   longitude   latitude        agbd  \
# 226043     52520500200220883 -120.898718  41.857705   56.699760
# 226155    174711100300205220 -120.895451  41.862932    0.919862
# 226156    174711100300205222 -120.894334  41.862338   54.759003
# 266370     64421100200220563 -120.903260  41.866773   43.625595
# 266372     64421100200220566 -120.901583  41.867660   42.969738
# ...                      ...         ...        ...         ...
# 10739573  174560500300291197 -118.588123  36.811295  605.784363
# 10739681   76920800200086263 -118.581961  36.805782   57.823112
# 10748046  174560300300291379 -118.561519  36.803085  101.434074
# 13920456  103610200200193053 -118.569528  36.824070   46.596722
# 13920460  103610200200193057 -118.567627  36.825404   40.198425
#
#           agbd_pi_lower  agbd_pi_upper    agbd_se beam_type  sensitivity  \
# 226043        21.643114     108.318810   2.995990      full     0.966562
# 226155     -9999.000000      14.765323   3.008004      full     0.970312
# 226156        20.456135     105.617134   2.994695      full     0.970751
# 266370        13.920637      89.849503   2.988128      full     0.957030
# 266372        13.552419      88.904152   2.987793      full     0.961133
# ...                 ...            ...        ...       ...          ...
# 10739573     458.516968     773.527588   3.703897      full     0.961634
# 10739681      22.335781     109.877083   2.996756      full     0.957344
# 10748046      21.057505     241.928513  11.099751  coverage     0.962761
# 13920456       1.802333     151.532364  11.104068  coverage     0.970274
# 13920460       0.733710     139.804062  11.104008  coverage     0.973113
#
#           pft_class  ...  SR_B7_2018  NDVI_2018 SR_B1_2019 SR_B2_2019  \
# 226043            6  ...    0.158397   0.353363   0.036107   0.044129
# 226155            6  ...    0.148639   0.313443   0.033713   0.042066
# 226156            6  ...    0.147475   0.329171   0.033735   0.043613
# 266370            6  ...    0.159404   0.288363   0.032181   0.039491
# 266372            6  ...    0.128385   0.430624   0.028644   0.037587
# ...             ...  ...         ...        ...        ...        ...
# 10739573          6  ...    0.068116   0.758527   0.021787   0.026884
# 10739681          6  ...    0.155066   0.528488   0.044800   0.052408
# 10748046          1  ...    0.057910   0.710446   0.013448   0.020384
# 13920456          1  ...    0.076129   0.692720   0.020498   0.027724
# 13920460          1  ...    0.078202   0.692119   0.022130   0.029524
#
#           SR_B3_2019  SR_B4_2019  SR_B5_2019  SR_B6_2019  SR_B7_2019  \
# 226043      0.063742    0.082229    0.173388    0.210451    0.152329
# 226155      0.060701    0.080343    0.163926    0.202136    0.142708
# 226156      0.061311    0.082339    0.170526    0.207157    0.143085
# 266370      0.057045    0.074513    0.162363    0.190687    0.134764
# 266372      0.058553    0.071630    0.180304    0.180384    0.120561
# ...              ...         ...         ...         ...         ...
# 10739573    0.048614    0.038611    0.279877    0.121251    0.067075
# 10739681    0.077384    0.079356    0.270942    0.229999    0.151357
# 10748046    0.044210    0.036348    0.233364    0.108473    0.054352
# 13920456    0.051399    0.045180    0.240424    0.135849    0.075603
# 13920460    0.055359    0.049033    0.255696    0.140040    0.077769
#
#           NDVI_2019
# 226043     0.357990
# 226155     0.345412
# 226156     0.351503
# 266370     0.369803
# 266372     0.432518
# ...             ...
# 10739573   0.759624
# 10739681   0.547772
# 10748046   0.730692
# 13920456   0.684858
# 13920460   0.678649
#
# [224523 rows x 54 columns]

# %%
load_pickle("/maps/fire-regen/data/rf/burned/3x3/gedi_match_1985.pkl")
# Out:
#                  shot_number   longitude   latitude        agbd  \
# 226043     52520500200220883 -120.898718  41.857705   56.699760
# 226155    174711100300205220 -120.895451  41.862932    0.919862
# 226156    174711100300205222 -120.894334  41.862338   54.759003
# 266370     64421100200220563 -120.903260  41.866773   43.625595
# 266372     64421100200220566 -120.901583  41.867660   42.969738
# ...                      ...         ...        ...         ...
# 10739573  174560500300291197 -118.588123  36.811295  605.784363
# 10739681   76920800200086263 -118.581961  36.805782   57.823112
# 10748046  174560300300291379 -118.561519  36.803085  101.434074
# 13920456  103610200200193053 -118.569528  36.824070   46.596722
# 13920460  103610200200193057 -118.567627  36.825404   40.198425
#
#           agbd_pi_lower  agbd_pi_upper    agbd_se beam_type  sensitivity  \
# 226043        21.643114     108.318810   2.995990      full     0.966562
# 226155     -9999.000000      14.765323   3.008004      full     0.970312
# 226156        20.456135     105.617134   2.994695      full     0.970751
# 266370        13.920637      89.849503   2.988128      full     0.957030
# 266372        13.552419      88.904152   2.987793      full     0.961133
# ...                 ...            ...        ...       ...          ...
# 10739573     458.516968     773.527588   3.703897      full     0.961634
# 10739681      22.335781     109.877083   2.996756      full     0.957344
# 10748046      21.057505     241.928513  11.099751  coverage     0.962761
# 13920456       1.802333     151.532364  11.104068  coverage     0.970274
# 13920460       0.733710     139.804062  11.104008  coverage     0.973113
#
#           pft_class  ...      slope      aspect soil SR_B1_1984  SR_B2_1984  \
# 226043            6  ...   1.666667  166.000000  0.0   0.048599    0.070351
# 226155            6  ...   2.000000  170.000000  0.0   0.050815    0.070694
# 226156            6  ...   1.777778  180.222222  0.0   0.050523    0.071812
# 266370            6  ...   2.333333  172.555556  0.0   0.050080    0.068719
# 266372            6  ...   2.888889  195.333333  0.0   0.046155    0.064589
# ...             ...  ...        ...         ...  ...        ...         ...
# 10739573          6  ...  29.000000  100.000000  0.0   0.036586    0.060605
# 10739681          6  ...  29.000000  109.666667  0.0   0.061157    0.087335
# 10748046          1  ...  27.111111  272.000000  0.0   0.023437    0.036443
# 13920456          1  ...  19.666667  266.000000  0.0   0.034724    0.050065
# 13920460          1  ...  25.333333  279.000000  0.0   0.035424    0.053292
#
#           SR_B3_1984  SR_B4_1984  SR_B5_1984  SR_B7_1984  NDVI_1984
# 226043      0.084729    0.169297    0.198797    0.146163   0.333522
# 226155      0.081647    0.187040    0.208568    0.138520   0.393282
# 226156      0.083716    0.187226    0.212202    0.142748   0.382820
# 266370      0.078691    0.175375    0.194453    0.126715   0.381478
# 266372      0.073610    0.174236    0.176216    0.115350   0.406744
# ...              ...         ...         ...         ...        ...
# 10739573    0.053352    0.310427    0.140764    0.073369   0.705963
# 10739681    0.094328    0.261635    0.246885    0.167792   0.472260
# 10748046    0.031170    0.177012    0.055300    0.027429   0.702418
# 13920456    0.044193    0.238456    0.088126    0.046963   0.690639
# 13920460    0.050639    0.231344    0.117115    0.065825   0.642457
#
# [224523 rows x 29 columns]

# %%
load_pickle("/maps/fire-regen/data/rf/burned/3x3/gedi_match_1990.pkl").columns
# Out:
# Index(['shot_number', 'longitude', 'latitude', 'agbd', 'agbd_pi_lower',
#        'agbd_pi_upper', 'agbd_se', 'beam_type', 'sensitivity', 'pft_class',
#        'gedi_year', 'gedi_month', 'absolute_time', 'geometry', 'severity',
#        'burn_year', 'burn_count', 'time_since_burn', 'elevation', 'slope',
#        'aspect', 'soil', 'SR_B1_1985', 'SR_B2_1985', 'SR_B3_1985',
#        'SR_B4_1985', 'SR_B5_1985', 'SR_B7_1985', 'NDVI_1985', 'SR_B1_1986',
#        'SR_B2_1986', 'SR_B3_1986', 'SR_B4_1986', 'SR_B5_1986', 'SR_B7_1986',
#        'NDVI_1986', 'SR_B1_1987', 'SR_B2_1987', 'SR_B3_1987', 'SR_B4_1987',
#        'SR_B5_1987', 'SR_B7_1987', 'NDVI_1987', 'SR_B1_1988', 'SR_B2_1988',
#        'SR_B3_1988', 'SR_B4_1988', 'SR_B5_1988', 'SR_B7_1988', 'NDVI_1988',
#        'SR_B1_1989', 'SR_B2_1989', 'SR_B3_1989', 'SR_B4_1989', 'SR_B5_1989',
#        'SR_B7_1989', 'NDVI_1989'],
#       dtype='object')

# %%
load_pickle("/maps/fire-regen/data/rf/burned/3x3/gedi_match_1990.pkl").columns
# Out:
# Index(['shot_number', 'longitude', 'latitude', 'agbd', 'agbd_pi_lower',
#        'agbd_pi_upper', 'agbd_se', 'beam_type', 'sensitivity', 'pft_class',
#        'gedi_year', 'gedi_month', 'absolute_time', 'geometry', 'severity',
#        'burn_year', 'burn_count', 'time_since_burn', 'elevation', 'slope',
#        'aspect', 'soil', 'SR_B1_1985', 'SR_B2_1985', 'SR_B3_1985',
#        'SR_B4_1985', 'SR_B5_1985', 'SR_B7_1985', 'NDVI_1985', 'SR_B1_1986',
#        'SR_B2_1986', 'SR_B3_1986', 'SR_B4_1986', 'SR_B5_1986', 'SR_B7_1986',
#        'NDVI_1986', 'SR_B1_1987', 'SR_B2_1987', 'SR_B3_1987', 'SR_B4_1987',
#        'SR_B5_1987', 'SR_B7_1987', 'NDVI_1987', 'SR_B1_1988', 'SR_B2_1988',
#        'SR_B3_1988', 'SR_B4_1988', 'SR_B5_1988', 'SR_B7_1988', 'NDVI_1988',
#        'SR_B1_1989', 'SR_B2_1989', 'SR_B3_1989', 'SR_B4_1989', 'SR_B5_1989',
#        'SR_B7_1989', 'NDVI_1989'],
#       dtype='object')

# %% [markdown]
# ### 2x2 filtered GEDI shots

# %%
# Obtain GEDI data.
gedi_burned, _ = gedi_pipeline.load_stage_9(2)

# %%
create_data.create_and_save_data_for_rf(gedi_burned, 1984, 2020, save=True, save_folder=f"{DATA_PATH}/rf/burned/2x2")
# Out:
# 2023-06-16 00:26:31,188 DEBUG: Matching gedi shots from 1984 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:26:31,202 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:28:08,403 DEBUG: Save DF in a pickle file. Training data for year 1985 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:28:09,139 DEBUG: Matching gedi shots from 1985 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:28:09,158 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:30:04,528 DEBUG: Save DF in a pickle file. Training data for year 1986 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:30:05,420 DEBUG: Matching gedi shots from 1986 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:30:05,445 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:32:03,982 DEBUG: Save DF in a pickle file. Training data for year 1987 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:32:04,930 DEBUG: Matching gedi shots from 1987 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:32:04,949 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:34:08,133 DEBUG: Save DF in a pickle file. Training data for year 1988 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:34:09,050 DEBUG: Matching gedi shots from 1988 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:34:09,069 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:35:37,132 DEBUG: Save DF in a pickle file. Training data for year 1989 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:35:38,366 DEBUG: Dropping columns from 1984 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 00:35:38,410 DEBUG: Matching gedi shots from 1989 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:35:38,426 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:37:17,667 DEBUG: Save DF in a pickle file. Training data for year 1990 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:37:19,106 DEBUG: Dropping columns from 1985 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 00:37:19,148 DEBUG: Matching gedi shots from 1990 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:37:19,162 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:39:13,218 DEBUG: Save DF in a pickle file. Training data for year 1991 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:39:14,362 DEBUG: Dropping columns from 1986 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 00:39:14,442 DEBUG: Matching gedi shots from 1991 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:39:14,454 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:40:47,075 DEBUG: Save DF in a pickle file. Training data for year 1992 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:40:48,374 DEBUG: Dropping columns from 1987 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 00:40:48,414 DEBUG: Matching gedi shots from 1992 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:40:48,434 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:42:35,480 DEBUG: Save DF in a pickle file. Training data for year 1993 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:42:36,694 DEBUG: Dropping columns from 1988 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 00:42:36,736 DEBUG: Matching gedi shots from 1993 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:42:36,753 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:44:16,740 DEBUG: Save DF in a pickle file. Training data for year 1994 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:44:17,949 DEBUG: Dropping columns from 1989 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 00:44:17,993 DEBUG: Matching gedi shots from 1994 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:44:18,008 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:46:07,179 DEBUG: Save DF in a pickle file. Training data for year 1995 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:46:08,271 DEBUG: Dropping columns from 1990 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 00:46:08,312 DEBUG: Matching gedi shots from 1995 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:46:08,333 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:49:34,747 DEBUG: Save DF in a pickle file. Training data for year 1996 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:49:35,890 DEBUG: Dropping columns from 1991 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 00:49:35,928 DEBUG: Matching gedi shots from 1996 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:49:35,954 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:51:21,143 DEBUG: Save DF in a pickle file. Training data for year 1997 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:51:22,572 DEBUG: Dropping columns from 1992 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 00:51:22,616 DEBUG: Matching gedi shots from 1997 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:51:22,631 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:54:04,639 DEBUG: Save DF in a pickle file. Training data for year 1998 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:54:05,756 DEBUG: Dropping columns from 1993 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 00:54:05,793 DEBUG: Matching gedi shots from 1998 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:54:05,808 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:56:03,592 DEBUG: Save DF in a pickle file. Training data for year 1999 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:56:04,793 DEBUG: Dropping columns from 1994 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 00:56:04,834 DEBUG: Matching gedi shots from 1999 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:56:04,845 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 00:58:12,453 DEBUG: Save DF in a pickle file. Training data for year 2000 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 00:58:13,506 DEBUG: Dropping columns from 1995 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 00:58:13,549 DEBUG: Matching gedi shots from 2000 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 00:58:13,564 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 01:00:19,884 DEBUG: Save DF in a pickle file. Training data for year 2001 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 01:00:21,111 DEBUG: Dropping columns from 1996 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 01:00:21,150 DEBUG: Matching gedi shots from 2001 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 01:00:21,166 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 01:01:47,052 DEBUG: Save DF in a pickle file. Training data for year 2002 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 01:01:48,123 DEBUG: Dropping columns from 1997 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 01:01:48,178 DEBUG: Matching gedi shots from 2002 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 01:01:48,189 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 01:03:07,704 DEBUG: Save DF in a pickle file. Training data for year 2003 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 01:03:08,707 DEBUG: Dropping columns from 1998 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 01:03:08,749 DEBUG: Matching gedi shots from 2003 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 01:03:08,762 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 01:05:13,237 DEBUG: Save DF in a pickle file. Training data for year 2004 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 01:05:14,386 DEBUG: Dropping columns from 1999 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 01:05:14,429 DEBUG: Matching gedi shots from 2004 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 01:05:14,443 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 01:11:27,359 DEBUG: Save DF in a pickle file. Training data for year 2005 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 01:11:28,738 DEBUG: Dropping columns from 2000 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 01:11:28,786 DEBUG: Matching gedi shots from 2005 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 01:11:28,802 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 01:15:59,417 DEBUG: Save DF in a pickle file. Training data for year 2006 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 01:16:00,374 DEBUG: Dropping columns from 2001 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 01:16:00,415 DEBUG: Matching gedi shots from 2006 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 01:16:00,425 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 01:17:31,067 DEBUG: Save DF in a pickle file. Training data for year 2007 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 01:17:32,207 DEBUG: Dropping columns from 2002 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 01:17:32,246 DEBUG: Matching gedi shots from 2007 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 01:17:32,260 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 01:19:19,084 DEBUG: Save DF in a pickle file. Training data for year 2008 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 01:19:20,206 DEBUG: Dropping columns from 2003 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 01:19:20,250 DEBUG: Matching gedi shots from 2008 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 01:19:20,263 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 01:21:44,753 DEBUG: Save DF in a pickle file. Training data for year 2009 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 01:21:45,949 DEBUG: Dropping columns from 2004 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 01:21:45,996 DEBUG: Matching gedi shots from 2009 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 01:21:46,010 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 01:25:55,148 DEBUG: Save DF in a pickle file. Training data for year 2010 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 01:25:56,330 DEBUG: Dropping columns from 2005 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 01:25:56,375 DEBUG: Matching gedi shots from 2010 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 01:25:56,389 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 01:30:02,485 DEBUG: Save DF in a pickle file. Training data for year 2011 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 01:30:04,048 DEBUG: Dropping columns from 2006 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 01:30:04,086 DEBUG: Matching gedi shots from 2011 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 01:30:04,100 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 01:32:58,334 DEBUG: Save DF in a pickle file. Training data for year 2012 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 01:33:00,125 DEBUG: Dropping columns from 2007 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 01:33:00,165 DEBUG: Matching gedi shots from 2012 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 01:33:00,176 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 01:35:38,975 DEBUG: Save DF in a pickle file. Training data for year 2013 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 01:35:40,560 DEBUG: Dropping columns from 2008 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 01:35:40,603 DEBUG: Matching gedi shots from 2013 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 01:35:40,617 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 01:38:17,025 DEBUG: Save DF in a pickle file. Training data for year 2014 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 01:38:18,368 DEBUG: Dropping columns from 2009 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 01:38:18,466 DEBUG: Matching gedi shots from 2014 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 01:38:18,477 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 01:43:04,211 DEBUG: Save DF in a pickle file. Training data for year 2015 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 01:43:05,368 DEBUG: Dropping columns from 2010 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 01:43:05,423 DEBUG: Matching gedi shots from 2015 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 01:43:05,436 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 01:50:30,308 DEBUG: Save DF in a pickle file. Training data for year 2016 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 01:50:31,586 DEBUG: Dropping columns from 2011 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 01:50:31,670 DEBUG: Matching gedi shots from 2016 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 01:50:31,690 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 01:52:16,573 DEBUG: Save DF in a pickle file. Training data for year 2017 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 01:52:18,380 DEBUG: Dropping columns from 2012 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 01:52:18,436 DEBUG: Matching gedi shots from 2017 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 01:52:18,446 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 01:54:45,300 DEBUG: Save DF in a pickle file. Training data for year 2018 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 01:54:46,885 DEBUG: Dropping columns from 2013 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 01:54:46,928 DEBUG: Matching gedi shots from 2018 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 01:54:46,943 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 01:57:53,873 DEBUG: Save DF in a pickle file. Training data for year 2019 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 01:57:55,498 DEBUG: Dropping columns from 2014 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
# 2023-06-16 01:57:55,545 DEBUG: Matching gedi shots from 2019 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:17]
# 2023-06-16 01:57:55,555 DEBUG: Sampling raster. [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:20]
# Process columns.
# 2023-06-16 02:03:22,391 DEBUG: Save DF in a pickle file. Training data for year 2020 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:30]
# 2023-06-16 02:03:23,811 DEBUG: Dropping columns from 2015 [in create_and_save_data_for_rf at /home/jk871/fire-regen/src/processing/rf/create_data.py:37]
#                  shot_number   longitude   latitude        agbd  \
# 226043     52520500200220883 -120.898718  41.857705   56.699760
# 226047     52520500200220890 -120.894793  41.859789  175.491180
# 226154    174711100300205219 -120.896009  41.863229    1.061925
# 226155    174711100300205220 -120.895451  41.862932    0.919862
# 226156    174711100300205222 -120.894334  41.862338   54.759003
# ...                      ...         ...        ...         ...
# 17320540   76920800200086273 -118.577213  36.809140   18.923901
# 17320555   76921100200080939 -118.568622  36.807751  268.527496
# 17320557   76921100200080942 -118.567204  36.808754   11.848656
# 17321525  174560500300291198 -118.587653  36.810958   86.728592
# 17321622   76920600200439166 -118.587844  36.809898   15.361624
#
#           agbd_pi_lower  agbd_pi_upper    agbd_se beam_type  sensitivity  \
# 226043        21.643114     108.318810   2.995990      full     0.966562
# 226047       106.367195     261.830261   3.114052      full     0.964391
# 226154     -9999.000000      15.315489   3.007025      full     0.963308
# 226155     -9999.000000      14.765323   3.008004      full     0.970312
# 226156        20.456135     105.617134   2.994695      full     0.970751
# ...                 ...            ...        ...       ...          ...
# 17320540   -9999.000000      96.729904  11.109355      full     0.981648
# 17320555     118.846939     478.381012  11.109919      full     0.988286
# 17320557       0.324685      39.873711   2.984896      full     0.962657
# 17321525      41.262825     148.889374   3.019974      full     0.961550
# 17321622       1.098112      46.115955   2.983040      full     0.952730
#
#           pft_class  ...  SR_B7_2018  NDVI_2018 SR_B1_2019 SR_B2_2019  \
# 226043            6  ...    0.158397   0.353363   0.036107   0.044129
# 226047            6  ...    0.127865   0.420029   0.028750   0.037192
# 226154            6  ...    0.159661   0.304480   0.032068   0.040166
# 226155            6  ...    0.148639   0.313443   0.033713   0.042066
# 226156            6  ...    0.147475   0.329171   0.033735   0.043613
# ...             ...  ...         ...        ...        ...        ...
# 17320540          1  ...    0.111804   0.617138   0.032824   0.039252
# 17320555          1  ...    0.096303   0.595243   0.025876   0.033348
# 17320557          6  ...    0.096606   0.636513   0.025027   0.033375
# 17321525          6  ...    0.079962   0.715815   0.024442   0.029995
# 17321622          6  ...    0.153258   0.524843   0.043461   0.052392
#
#           SR_B3_2019  SR_B4_2019  SR_B5_2019  SR_B6_2019  SR_B7_2019  \
# 226043      0.063742    0.082229    0.173388    0.210451    0.152329
# 226047      0.056981    0.069492    0.174883    0.176470    0.123303
# 226154      0.058520    0.077087    0.160722    0.198272    0.143244
# 226155      0.060701    0.080343    0.163926    0.202136    0.142708
# 226156      0.061311    0.082339    0.170526    0.207157    0.143085
# ...              ...         ...         ...         ...         ...
# 17320540    0.063373    0.059297    0.262915    0.186637    0.110627
# 17320555    0.055198    0.055897    0.229317    0.158198    0.097326
# 17320557    0.058965    0.055327    0.263443    0.161013    0.091775
# 17321525    0.051950    0.044972    0.276339    0.135382    0.078381
# 17321622    0.078677    0.083740    0.274994    0.221435    0.149283
#
#           NDVI_2019
# 226043     0.357990
# 226047     0.434228
# 226154     0.353359
# 226155     0.345412
# 226156     0.351503
# ...             ...
# 17320540   0.631126
# 17320555   0.609922
# 17320557   0.653635
# 17321525   0.721932
# 17321622   0.533686
#
# [416535 rows x 54 columns]
